# %%
import pandas as pd

# %%
df = pd.read_csv("POIs_location_catchments.csv")

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0           1256  Všeobecná ambulancia pre deti a dorast, MUDr. ...
# 1           1257  Všeobecná ambulancia pre deti a dorast, MUDr. ...
# 2           1258  Všeobecná ambulancia pre deti a dorast, MUDr. ...
# 3           1259  Všeobecná ambulancia pre deti a dorast, MUDr. ...
# 4           1260  Všeobecná ambulancia pre deti a dorast, MUDr. ...
# ...          ...                                                ...
# 3168        1251  Všeobecná ambulancia pre dospelých, Košice-Sev...
# 3169        1252  Všeobecná ambulancia pre dospelých, MUDr. Zlat...
# 3170        1253  Všeobecná ambulancia pre dospelých, Košice-Juh...
# 3171        1254  Všeobecná ambulancia pre dospelých, Košice-Záp...
# 3172        1255  Všeobecná ambulancia pre dospelých, Košice-Síd...
#
#                                    typ_0                               typ_1  \
# ...

# %%
import folium

# %%
map = folium.Map(location=[48.754977, 21.267500], zoom_start=10)

# %%
first_10 = df.loc[:9]

# %%
for index, row in first_10.iterrows():
    folium.Marker(location=[row['y'], row['x']], popup=row['name']).add_to(map)
